# %%
import os
from datasets import DatasetDict, load_dataset
from transformers import BertTokenizer
from sklearn.model_selection import train_test_split

def load_bio_data(file_path):
    """
    Load BIO-formatted data into a structured dataset.

    Args:
        file_path (str): Path to the BIO file.

    Returns:
        list of dict: Contains tokens and corresponding BIO labels.
    """
    sentences = []
    labels = []
    with open(file_path, 'r', encoding='utf-8') as f:
        current_tokens = []
        current_labels = []

        for line in f:
            if line.strip() == "":
                # End of a sentence
                if current_tokens:
                    sentences.append(current_tokens)
                    labels.append(current_labels)
                    current_tokens = []
                    current_labels = []
            else:
                token, tag = line.strip().split()
                current_tokens.append(token)
                current_labels.append(tag)

        # Add the last sentence
        if current_tokens:
            sentences.append(current_tokens)
            labels.append(current_labels)

    return sentences, labels

# Load BIO data
file_path = "./resources/all_event_data.bio"
tokens, labels = load_bio_data(file_path)

# %%
# Split into train and test sets
train_tokens, test_tokens, train_labels, test_labels = train_test_split(tokens, labels, test_size=0.2, random_state=42)

# %%
from transformers import BertTokenizerFast

# Load the fast tokenizer
tokenizer = BertTokenizerFast.from_pretrained("bert-base-uncased")

# Define label mapping
unique_labels = sorted(set(tag for label_list in labels for tag in label_list))
label2id = {label: i for i, label in enumerate(unique_labels)}
id2label = {i: label for label, i in label2id.items()}

# %%
def encode_data(tokens, labels, tokenizer, max_length=128):
    """
    Encode tokens and labels into BERT-compatible format.

    Args:
        tokens (list of list): Tokenized sentences.
        labels (list of list): BIO labels.
        tokenizer: Tokenizer object.
        max_length (int): Maximum sequence length.

    Returns:
        dict: Encoded inputs and labels.
    """
    encodings = tokenizer(tokens, is_split_into_words=True, truncation=True, padding=True, max_length=max_length)

    encoded_labels = []
    for i, label_list in enumerate(labels):
        word_ids = encodings.word_ids(batch_index=i)
        label_ids = []
        previous_word_id = None

        for word_id in word_ids:
            if word_id is None:
                label_ids.append(-100)  # Ignore padding tokens
            elif word_id != previous_word_id:
                label_ids.append(label2id[label_list[word_id]])
            else:
                label_ids.append(-100)  # Ignore subwords
            previous_word_id = word_id

        encoded_labels.append(label_ids)

    encodings["labels"] = encoded_labels
    return encodings

# Encode train and test data
train_encodings = encode_data(train_tokens, train_labels, tokenizer)
test_encodings = encode_data(test_tokens, test_labels, tokenizer)

# %%
import torch

class NERDataset(torch.utils.data.Dataset):
    def __init__(self, encodings):
        self.encodings = encodings

    def __len__(self):
        return len(self.encodings["input_ids"])

    def __getitem__(self, idx):
        return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}

# Create datasets
train_dataset = NERDataset(train_encodings)
test_dataset = NERDataset(test_encodings)

# %%
from transformers import BertForTokenClassification

# Load pre-trained BERT model for token classification
model = BertForTokenClassification.from_pretrained(
    "bert-base-uncased",
    num_labels=len(unique_labels),
    id2label=id2label,
    label2id=label2id
)
# Out:
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from torch.utils.data import DataLoader
from transformers import AdamW

# DataLoaders
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16)

# Optimizer
optimizer = AdamW(model.parameters(), lr=5e-5)
# Out:
# c:\Users\Gilchris\UNI\hackathon-projects\buffay\venv\Lib\site-packages\transformers\optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
from torch.nn import CrossEntropyLoss
from torch.optim import AdamW
from tqdm import tqdm

# Use GPU if available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model.to(device)

# Training loop
num_epochs = 20
for epoch in range(num_epochs):
    model.train()
    total_loss = 0

    for batch in tqdm(train_loader):
        # Move batch to device
        inputs = {key: val.to(device) for key, val in batch.items()}

        # Forward pass
        outputs = model(**inputs)
        loss = outputs.loss
        total_loss += loss.item()

        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print(f"Epoch {epoch + 1}: Loss = {total_loss / len(train_loader):.4f}")
# Out:
# 100%|██████████| 4/4 [00:00<00:00,  4.05it/s]
# Epoch 1: Loss = 1.1290
# 100%|██████████| 4/4 [00:00<00:00,  5.32it/s]
# Epoch 2: Loss = 0.3063
# 100%|██████████| 4/4 [00:00<00:00,  5.57it/s]
# Epoch 3: Loss = 0.2670
# 100%|██████████| 4/4 [00:00<00:00,  5.41it/s]
# Epoch 4: Loss = 0.3171
# 100%|██████████| 4/4 [00:00<00:00,  5.72it/s]
# Epoch 5: Loss = 0.2860
# 100%|██████████| 4/4 [00:00<00:00,  5.55it/s]
# Epoch 6: Loss = 0.2771
# 100%|██████████| 4/4 [00:00<00:00,  5.69it/s]
# Epoch 7: Loss = 0.2541
# 100%|██████████| 4/4 [00:00<00:00,  5.75it/s]
# Epoch 8: Loss = 0.2394
# 100%|██████████| 4/4 [00:00<00:00,  5.60it/s]
# Epoch 9: Loss = 0.2296
# 100%|██████████| 4/4 [00:00<00:00,  5.94it/s]
# Epoch 10: Loss = 0.1913

# %%
from sklearn.metrics import classification_report

model.eval()
predictions, true_labels = [], []

with torch.no_grad():
    for batch in test_loader:
        inputs = {key: val.to(device) for key, val in batch.items() if key != "labels"}
        labels = batch["labels"].to(device)

        outputs = model(**inputs)
        logits = outputs.logits
        preds = torch.argmax(logits, dim=2)

        # Collect predictions and true labels
        predictions.extend(preds.cpu().numpy())
        true_labels.extend(labels.cpu().numpy())

# Convert predictions and labels to flat lists for classification report
flat_preds = []
flat_labels = []

for pred, true_label in zip(predictions, true_labels):
    for p, l in zip(pred, true_label):
        if l != -100:  # Only include non-padding tokens
            flat_preds.append(id2label[p])  # Convert predicted IDs to labels
            flat_labels.append(id2label[l])  # Convert true IDs to labels

print(classification_report(flat_labels, flat_preds, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#       B-FOOD     0.0000    0.0000    0.0000         5
#  B-FOOD-TIME     0.4444    0.4444    0.4444         9
#       E-FOOD     0.0000    0.0000    0.0000         1
#       I-FOOD     0.0000    0.0000    0.0000         5
#  I-FOOD-TIME     0.0000    0.0000    0.0000         7
#            O     0.9837    0.9983    0.9910      1211
#
#     accuracy                         0.9798      1238
#    macro avg     0.2380    0.2405    0.2392      1238
# weighted avg     0.9655    0.9798    0.9726      1238
# c:\Users\Gilchris\UNI\hackathon-projects\buffay\venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Gilchris\UNI\hackathon-projects\buffay\venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Gilchris\UNI\hackathon-projects\buffay\venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
model.save_pretrained("./ner_model")
tokenizer.save_pretrained("./ner_model")
# Out:
# ('./ner_model\\tokenizer_config.json',
#  './ner_model\\special_tokens_map.json',
#  './ner_model\\vocab.txt',
#  './ner_model\\added_tokens.json',
#  './ner_model\\tokenizer.json')

# %%
# Test the saved model
loaded_model = BertForTokenClassification.from_pretrained("./ner_model")
loaded_tokenizer = BertTokenizerFast.from_pretrained("./ner_model")

# Tokenize a sentence
sentence = """
Come and join us as we step into the new year with exciting activities! (  ≧ᗜ≦) ⋆⭒˚.⋆

Explore Middle Eastern culture through fun games and savor rich, flavorful, and exquisite food prepared just for YOU! (˶˃ ᵕ ˂˶)❤️


Save the date!🗓️🙀


📅Date : 24 January 2025

📍Venue : SMUC ALC 3.1-3.2

⏰Time: 4:00PM - 7:00PM



Food and refreshments will be provided!🍽️


Sign up HERE by clicking on the RSVP button below SMU Al Khaleej : Step Into the Middle East! Forms are open until 17 January 2025. Hurry as slots are limited! 😱

 

If you have any questions or concerns, do reach out to @hahahhaha via Telegram.

 

Follow us on Instagram and join our Telegram Group for our latest updates!

 

Should you wish to unsubscribe:

Internal recipients of SMU, please visit <link> to filter away this EDM.  
"""

tokens = loaded_tokenizer.tokenize(sentence)
inputs = loaded_tokenizer(sentence, return_tensors="pt")

# Make a prediction
outputs = loaded_model(**inputs)
logits = outputs.logits
preds = torch.argmax(logits, dim=2)

# Decode the prediction
decoded_preds = [id2label[p] for p in preds[0].numpy()]

# Print all label that starts with B-FOOD
food_labels = [label for label in decoded_preds if label.startswith("B-FOOD")]
print(food_labels)
# Out:
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# []

# %%
# load csv
import pandas as pd
df = pd.read_csv('./resources/all_event_data.csv')

# for each row in df where df["is_event"] == "Yes" and df["food_mentioned"] == "Yes"
# get "body" and run the model on it
for index, row in df.iterrows():
    if row["is_event"] == "Yes" and row["food_mentioned"] == "Yes":
        tokens = loaded_tokenizer.tokenize(row["body"])
        inputs = loaded_tokenizer(row["body"], return_tensors="pt", truncation=True, padding=True, max_length=512)

        # Make a prediction
        outputs = loaded_model(**inputs)
        logits = outputs.logits
        preds = torch.argmax(logits, dim=2)

        # Decode the prediction
        decoded_preds = [id2label[p] for p in preds[0].numpy()]

        if len(set(decoded_preds)) > 1:
            # Print the word and label that is not O
            for token, label in zip(tokens, decoded_preds):
                if label != "O":
                    print(token, label)
            print(row["body"])
            print("\n\n")
# Out:
# 18 I-FOOD-TIME
# : B-FOOD-TIME
# nov B-FOOD-TIME
# - I-FOOD-TIME
# ##pm I-FOOD-TIME
# ##pm I-FOOD-TIME
# SMU Classification: Restricted
#
#
#
# Dear SCIS Students,
#
#
#
# Gentle reminder about the Ascenda?s sharing happening this Friday, 22 Nov 2024, 4pm - 5.30pm.
#
# If you are keen to attend, do sign up here (https://smu.sg/cs301-ascenda) by today, 18 Nov 2024.
#
#
#
# Thanks.
#
#
#
# Regards,
#
# Office of the Dean
#
# School of Computing and Information Systems
#
#
#
# From: School of Computing and Information Systems
# Sent: Friday, October 18, 2024 3:42 PM
# Subject: Ascenda Loyalty Talk - Friday, 22 Nov 2024, 4pm - 5.30pm
#
#
#
# Dear SCIS Students,
#
#
#
# Ascenda (https://www.ascenda.com)  will be doing a sharing on Friday (22 Nov).
#
#
#
# Details as follow:
#
#
#
# Venue: SMU SCIS1 SR B1-1.
#
# Time: 22 Nov (Friday) Week 14, 4pm - 5.30pm
#
#
#
# Agenda:
#
# 1. Life as an Ascenda Engineer sharing
#
# 2. Configuration Management Automated
#
# 3. Q&A / mingling
#
#
#
# 4 reasons why you should attend the talk:
#
# 1. Learn about what is configuration Management, and how to automate it.
#
# 2. Learn about what it takes to be an engineer working at Ascenda (especially useful if you are considered to be a software engineer in the future)
#
# 3. Network with Ascenda folks and SCIS alumnus. Singapore is small, they may be your RO, boss or even startup partners in future.
#
# 4. Enjoy the free food!
#
#
#
# Do sign up here (https://smu.sg/cs301-ascenda) by 18 Nov.
#
#
#
# Thank you.
#
#
#
# Regards,
#
# Office of the Dean
#
# School of Computing and Information Systems
#
#
#
#
# november B-FOOD-TIME
# 202 I-FOOD-TIME
# . B-FOOD-TIME
# 30 I-FOOD-TIME
# ##pm I-FOOD-TIME
# . I-FOOD-TIME
# 00pm I-FOOD-TIME
# Get into the holiday spirit for this?
#
# ???? PASKUHAN ????
#
#  <https://www.smuicon.com/activities>
#
#
# Immerse yourself in the festive ?ber? months with a parol-making workshop,
# and take home traditional Filipino ornamental lanterns for this Christmas season.
#
# The fun doesn?t stop there, celebrate the holiday season with friends, old and new,
# over our favourite Filipino snacks and desserts!
#
# Details:
# Date ??: Saturday, 9 November 2024
# Time ??: 1.30pm to 5.00pm
# Location ??: SMU Connexion Active Learning Classroom 3-1
#
# Sign up here <https://www.smuicon.com/activities>  by 8 November 2024
#
#
# Feel free to email us at smubarkada@sa.smu.edu.sg <mailto:smubarkada@sa.smu.edu.sg>  if you have any questions
# or reach out to us on Telegram:
#
# Jana (President) - @janana21
# Justin (Vice-President) - @justindionio
# Andrew (Events Director) - @andrewso1
#
# Want to know more about us?
# Follow us on Instagram @smu.barkada <http://instagram.com/smu.barkada>
#
#
# Kita Kits!
#
# Translations:
# Kita kits! - See you there!
# ?ber months ? referring to September, October, November, December,
# which is commonly celebrated as the Christmas season in the Philippines
# Parol ? Filipino ornamental lanterns for Christmas
#
# *Note: Food to be served is non-Halal and non-vegetarian.
#
# Should you wish to unsubscribe:
# Internal recipients of SMU, please visit
# https://smu.sg/emailrulesstudent to filter away this EDM.
#
#
#
#
#
# pm I-FOOD-TIME
# ?
#
#
#
#
#
#
#
# ?? SMU Gourmet Club Welfare Drive 2024 is here! ??
# Join us for Treats & Eats ? a fun-filled afternoon of goodies, popcorn, and more! ??
#
#
#
# ?? Date: Wednesday, 20 Nov 2024
# ?? Time: 2 PM - 4 PM
# ?? Location: Opposite Koufu
#
#
#
# ? Highlights:
#
# *	Free goodies ??
# *	Live popcorn station ??
# *	Fun vibes ??
#
#
#
# ? Only 50 slots available, and it's MEMBERS ONLY! Sign up HERE <https://forms.gle/cBiXnN7dA8nAfbr97> ! So bring your own bag, come hungry, and get ready for some treats! ??
#
#
#
# If you have any questions, feel free to reach out to Hester (@hesterkoh) or Jia Wen (@ekjiawen) on Telegram!
#
#
#
# Stay connected with us on Instagram <https://www.instagram.com/smugourmetclub?igsh=MXVqemlseWFtazVvaA==> , Telegram <https://t.me/smugourmetclub>  & LinkedIn <https://www.linkedin.com/company/smu-gourmet-club/>  via the link in our bio for more foodie events!
#
#
#
#
#
#
#
# Should you wish to unsubscribe:
#
# Internal recipients of SMU, please visit https://smu.sg/emailrules <https://smu.sg/emailrules> , to filter away future EDMs
#
#
#
#
#
#
#
#
#
#
#
#
# : I-FOOD-TIME
# - I-FOOD-TIME
# november I-FOOD-TIME
# 202 I-FOOD-TIME
# pm I-FOOD-TIME
# : I-FOOD-TIME
#
#
#
# Free Chagee and Fun: Learn about Blockchain! ????
#
#
#
# Prepping for finals and need something to freshen you up? We got you ?? Come hop down anytime between 12pm to 3:30pm tomorrow to enjoy a cup of FREE Cup of Chagee when you learn more about Blockchain and Jupiter ! ???????
#
#
#
#
# Open to everyone, but cups are limited?so fastest legs first before they're gone! ??
#
#
#
#
#
# ?? Location: SMU Connexion, Active Learning Classroom 4-1 ??
# ?? Date: Wednesday, 6 November 2024 ??
# ?? Time: 12 PM - 3:30 PM ??
#
#
# Feel free to contact us via our Telegram handles for any queries:
#
# Ashley @x0MeePok
#
# We look forward to seeing you there!
#
# Follow SMU Blockchain:
# Instagram <https://www.instagram.com/smublockchain/>   <https://www.instagram.com/smublockchain/> | LinkedIn <https://sg.linkedin.com/company/smub>  | Telegram <https://t.me/smublockchainclub>
#
#  Should you wish to unsubscribe:
# Internal recipients of SMU, please visit
# https://smu.sg/emailrulesstudent to filter away this EDM
#
#
#
#
# maple I-FOOD-TIME
# maple I-FOOD-TIME
# november B-FOOD-TIME
# 202 I-FOOD-TIME
# ##4 I-FOOD-TIME
# . I-FOOD-TIME
# 00 I-FOOD-TIME
# pm I-FOOD-TIME
# opening I-FOOD-TIME
# . I-FOOD-TIME
# 05 I-FOOD-TIME
# pm I-FOOD-TIME
# panel I-FOOD-TIME
# . I-FOOD-TIME
# 00 I-FOOD-TIME
# pm I-FOOD-TIME
# q I-FOOD-TIME
# . I-FOOD-TIME
# 20 I-FOOD-TIME
# pm I-FOOD-TIME
# concluding I-FOOD-TIME
# . I-FOOD-TIME
# 30 I-FOOD-TIME
# pm I-FOOD-TIME
# end I-FOOD-TIME
# . I-FOOD-TIME
# 30 I-FOOD-TIME
# ##pm I-FOOD-TIME
# . I-FOOD-TIME
# november B-FOOD-TIME
# 202 I-FOOD-TIME
# ##4 I-FOOD-TIME
# , I-FOOD-TIME
# 3 I-FOOD-TIME
# . I-FOOD-TIME
# 00pm I-FOOD-TIME
# ? I-FOOD-TIME
# . I-FOOD-TIME
# 30 I-FOOD-TIME
# ##pm I-FOOD-TIME
# venue I-FOOD-TIME
# stamford I-FOOD-TIME
# ##0 I-FOOD-TIME
# ) I-FOOD-TIME
# november B-FOOD-TIME
# 202 I-FOOD-TIME
# ##4 I-FOOD-TIME
# , I-FOOD-TIME
# SMU Classification: Restricted
#
#
#
# Please click here <https://business.smu.edu.sg/newsletter/4th-mapletree-real-estate-forum-smu-0>  if you are unable to view this page.
#
#
#
#
#
#
#
#
#
#
#
#
#
# 4TH MAPLETREE REAL ESTATE FORUM AT SMU
#
#
#
# The Mapletree Real Estate Programme is pleased to invite you to the 4th Mapletree Real Estate Forum at SMU on 8 November 2024.
#
#
#
# IS STUDENT ACCOMMODATION A VIABLE ASSET CLASS?
#
# Join us at this forum to explore current trends in the student housing market, the impact of changing demographics, and the rise of international student mobility. Industry experts will discuss investment returns, risk factors, and the challenges associated with this unique property sector.
#
#
#
#
#
# SPEAKER
#
#
#
#
# Mr Matt Walker
# Chief Executive Officer,
# Student Housing,
# Mapletree Investments
#
# PANELLIST
#
#
#
#
# Ms Joy Wang
# Head,
#
# ASEAN Equity Research and ASEAN Property,
#
# HSBC Bank
#
# MODERATOR
#
#
#
#
# Prof John Sequeira <https://faculty.smu.edu.sg/profile/john-sequeira-1736>
#
# Associate Professor of Finance (Practice)
# Singapore Management University
#
# ???PROGRAMME
#
# 3.00 PM
#
# Opening Remarks
#
# 3.05 PM
#
# Panel Discussion
#
# 4.00 PM
#
# Q&A
#
# 4.20 PM
#
# Concluding Remarks
#
# 4.30 PM
#
# End of Forum
#
# Light refreshments will be provided from 2.30pm.
#
#
# DATE & TIME
#
# 8 November 2024, Friday
# 3.00pm ? 4.30pm
#
#
#
# VENUE
#
# Ngee Ann Kong Si Auditorium,
# SMU School of Accountancy, Level 2
# (60 Stamford Road S178900)
#
#
#
#
#
#
#
#
#
#  <https://forms.office.com/r/SXga7a8EpH>
#
# Register by 5 November 2024, Tuesday.
#
# A confirmation email will be sent upon successful registration.
#
# ________________________________
#
# To unsubscribe to future mailing list, please click here <mailto:realestate@smu.edu.sg> .
#
# ? Copyright 2024 by Singapore Management University. All Rights Reserved.
#
#
#
#
#
#
#
#
#
#
# november B-FOOD-TIME
# . B-FOOD-TIME
# 30 I-FOOD-TIME
# ##pm I-FOOD-TIME
# . B-FOOD-TIME
# 00pm I-FOOD-TIME
# Get into the holiday spirit for this?
#
#
#
# ???? PASKUHAN ????
#
#
#
#  <https://www.smuicon.com/activities>
#
#
#
# Immerse yourself in the festive ?ber? months with a parol-making workshop,
#
# and take home traditional Filipino ornamental lanterns for this Christmas season.
#
#
#
# The fun doesn?t stop there, celebrate the holiday season with friends, old and new,
#
# over our favourite Filipino snacks and desserts!
#
#
#
# Details:
#
# Date ??: Thursday, 9 November 2024
#
# Time ??: 1.30pm to 5.00pm
#
# Location ??: SMU Connexion Active Learning Classroom 3-1
#
#
#
# Sign up here <https://www.smuicon.com/activities>  by 8 November 2024
#
#
#
#
#
# Feel free to email us at smubarkada@sa.smu.edu.sg <mailto:smubarkada@sa.smu.edu.sg>  if you have any questions
#
# or reach out to us on Telegram:
#
#
#
# Jana (President) - @janana21
#
# Justin (Vice-President) - @justindionio
#
# Andrew (Events Director) - @andrewso1
#
#
#
# Want to know more about us?
#
# Follow us on Instagram @smu.barkada <http://instagram.com/smu.barkada>
#
#
#
#
#
# Kita Kits!
#
#
#
# Translations:
#
# Kita kits! - See you there!
#
# ?ber months ? referring to September, October, November, December,
#
# which is commonly celebrated as the Christmas season in the Philippines
#
# Parol ? Filipino ornamental lanterns for Christmas
#
#
#
# *Note: Limited slots available. You will receive a confirmation email upon successful registration.
#
# Food to be served is non-Halal and non-vegetarian.
#
#
#
#
# Should you wish to unsubscribe:
#
# Internal recipients of SMU, please visit
#
# https://smu.sg/emailrulesstudent to filter away this EDM.
#
#
#
#
#
#
# november B-FOOD-TIME
# . B-FOOD-TIME
# 30 I-FOOD-TIME
# ##pm I-FOOD-TIME
# . B-FOOD-TIME
# 00pm I-FOOD-TIME
# Get into the holiday spirit for this?
#
#
#
# ???? PASKUHAN ????
#
#
#
#  <https://www.smuicon.com/activities>
#
#
#
# Immerse yourself in the festive ?ber? months with a parol-making workshop,
#
# and take home traditional Filipino ornamental lanterns for this Christmas season.
#
#
#
# The fun doesn?t stop there, celebrate the holiday season with friends, old and new,
#
# over our favourite Filipino snacks and desserts!
#
#
#
# Details:
#
# Date ??: Thursday, 9 November 2024
#
# Time ??: 1.30pm to 5.00pm
#
# Location ??: SMU Connexion Active Learning Classroom 3-1
#
#
#
# Sign up here <https://www.smuicon.com/activities>  by 8 November 2024
#
#
#
#
#
# Feel free to email us at smubarkada@sa.smu.edu.sg <mailto:smubarkada@sa.smu.edu.sg>  if you have any questions
#
# or reach out to us on Telegram:
#
#
#
# Jana (President) - @janana21
#
# Justin (Vice-President) - @justindionio
#
# Andrew (Events Director) - @andrewso1
#
#
#
# Want to know more about us?
#
# Follow us on Instagram @smu.barkada <http://instagram.com/smu.barkada>
#
#
#
#
#
# Kita Kits!
#
#
#
# Translations:
#
# Kita kits! - See you there!
#
# ?ber months ? referring to September, October, November, December,
#
# which is commonly celebrated as the Christmas season in the Philippines
#
# Parol ? Filipino ornamental lanterns for Christmas
#
#
#
# *Note: Limited slots available. You will receive a confirmation email upon successful registration.
#
# Food to be served is non-Halal and non-vegetarian.
#
#
#
#
# Should you wish to unsubscribe:
#
# Internal recipients of SMU, please visit
#
# https://smu.sg/emailrulesstudent to filter away this EDM.
#
#
#
#
#
#
# : B-FOOD-TIME
# : B-FOOD-TIME
#
# ?Get ready to level up your evening with Etherlink and SMU Blockchain Club! ?????
# Join us for an electrifying session that dives into the future of gaming on the blockchain. ?We're thrilled to have the head of gaming from Trilitech to unravel the exciting benefits of merging gaming with blockchain technology.
# Discover how games like Sugarverse and Battlerise are breaking new ground on Etherlink, offering unique experiences that are as innovative as they are entertaining. ?We will also be giving out NFTs on Etherlink and merch as well. ????
# ?? Location: SMU Connexion Level 4, Greenhouse
# ?? Date: Wednesday, 6 November 2024
# ?? Time: 7PM - 9PM
#
#
# SIGN UP HERE <https://lu.ma/fwdtufcl> !
#
#
#
#
# Agenda:
#
#
# 7:00 PM - 7:30 PM: Registrations & Networking ??
#   7:30 PM - 8:15 PM: Sharing by Jeremy, Head of Gaming at Trilitech ?????
#
# 8:15 PM - 8:30 PM: Q&A ??
#
# 8:30 PM - 9:00 PM: Snacks & Networking ??
#
#
#
#
#
# Don?t miss out on this unique opportunity to engage with experts and explore intersections with gaming in the rapidly evolving blockchain landscape!
#
#
# Feel free to contact us via our Telegram handles for any queries:
#
# Anthony @YPSONO
# Ashley @x0MeePok
#
# We look forward to seeing you there!
#
# Follow SMU Blockchain:
# Instagram <https://www.instagram.com/smublockchain/>   <https://www.instagram.com/smublockchain/> | LinkedIn <https://sg.linkedin.com/company/smub>  | Telegram <https://t.me/smublockchainclub>
#
#  Should you wish to unsubscribe:
# Internal recipients of SMU, please visit
# https://smu.sg/emailrulesstudent to filter away this EDM
#
#
#
#
# . B-FOOD-TIME
# pm B-FOOD-TIME
# . B-FOOD-TIME
# Dear Teams,
#
#
#
# Thank you to everyone who participated in this evening's Impact Pitching Workshop. We hope you found Ruo Mei's insights valuable. The slides have been uploaded to the programme schedule link under "Related Documents." Please note that the deck is not for further circulation.
#
#
#
# The submission deadline has been extended to 4th November (Monday) 11.59hrs, to allow more time for all teams. Please ensure you submit your deck on time.
#
#
#
# Lastly, if you require an excuse chit, please email me by 1st November (Friday) by 12 PM.
#
#
#
# Thank you, and enjoy the Deepavali?s public holiday!
#
#
#
# Best regards,
#
# Silvia
#
# From: NTU Innovation and Entrepreneurship
# Sent: Monday, 28 October 2024 5:04 pm
# Subject: (UPDATES) Port63 Challenge 2024 - Semi-Finals
#
#
#
# Dear Teams,
#
#
#
# Do take note that the agenda, pitching sequence and judging panel for the respective Semi-Final Events have been updated in the programme schedule. (Link <https://evanescent-cylinder-eb3.notion.site/11fca7c0444480a2977aef8e59c159af?v=8d007bdf24824f5c935fae1884ceb704&pvs=4> ) For information and noting, please.
#
#
#
# Impact Pitching Workshop
#
# For teams that have not registered for the postponed workshop, re-scheduled to 30 October, Wednesday 5PM to 9.30PM (Dinner will be provided), please do so asap at https://forms.office.com/r/LnDgNgNJ5r
#
#
#
# Rehearsal Slot for Semi-Finals
#
# For teams that require a venue, with AV settings to practise your pitch, you may book a slot here. https://calendly.com/innovates/port63-challenge-semi-finals-rehearsal <https://calendly.com/innovates/port63-challenge-semi-finals-rehearsal>
#
# Submission of Deck
#
# Please be reminded to upload your deck by end of 3 Nov, Sunday. https://event.ntu.edu.sg/submission-to-the-port63-challenge-semi-finals/register <https://event.ntu.edu.sg/submission-to-the-port63-challenge-semi-finals/register>
#
# All the best for your upcoming pitches!
#
#
#
# Thank you
#
# Silvia Yu
#
#
#
#
# ##pm B-FOOD-TIME
# ##pm B-FOOD-TIME
# ?
#
#
#
#
#
#
# READY FOR FINALS?
#
#
#
# ??Ellipsis is back with our Bi-Annual Finals Welfare Drive! ??
#
#
# We know finals can be tough, so we?re here to make it a little easier! Swing by to grab your goodies and snap a photo with your chingus before you start mugging! ??
#
#
#
# Stay tuned for more details, signups are coming soon! ??
#
#
#
# Collection Details
#
# Date: Tuesday, 5 November 2024
#
# Time: 12pm ? 5pm
#
# Venue: The Alcove (B1 near IS lounge)
#
#
#
# The link ?? to sign up will be released exclusively through Ellipsis? Telegram channel <https://t.me/scisbytes>  on Thursday, 31 October 2024, at a random time between 12pm ? 5pm. Make sure to join the channel and keep your notifications on so you don?t miss out!
#
#
#
# If you have any questions, feel free to contact us via telegram Jing Ren (@immaBEAST) or Xing Ying (@xingyingintherain)!
#
#
#
# Brought to you by Ellipsis, the student representative body of
# School of Computing and Information Systems (SCIS)
#
#
#
# Facebook <https://www.facebook.com/SMUELLIPSIS/>  | Instagram <https://www.instagram.com/smuellipsis/>  | LinkedIn <https://sg.linkedin.com/company/ellipsis-smu-computing-and-information-systems-society>  | Telegram <https://t.me/scisbytes>
#
# Website: ellipsis.scis.smu.edu.sg <https://ellipsis.scis.smu.edu.sg/>
#
# Email: ellipsis@sa.smu.edu.sg <mailto:ellipsis@sa.smu.edu.sg>
#
#
#
# Should you wish to unsubscribe:
#
# Internal recipients of SMU, please visit https://smu.sg/emailrulesstudent <https://smu.sg/emailrulesstudent> .
#
#
#
#
#
#
#
#
# november B-FOOD-TIME
# . B-FOOD-TIME
# 30 I-FOOD-TIME
# ##pm I-FOOD-TIME
# . B-FOOD-TIME
# 00pm I-FOOD-TIME
# Get into the holiday spirit for this?
#
#
#
# ???? PASKUHAN ????
#
#
#
#  <https://www.smuicon.com/activities>
#
#
#
# Immerse yourself in the festive ?ber? months with a parol-making workshop,
#
# and take home traditional Filipino ornamental lanterns for this Christmas season.
#
#
#
# The fun doesn?t stop there, celebrate the holiday season with friends, old and new,
#
# over our favourite Filipino snacks and desserts!
#
#
#
# Details:
#
# Date ??: Saturday, 9 November 2024
#
# Time ??: 1.30pm to 5.00pm
#
# Location ??: SMU Connexion Active Learning Classroom 3-1
#
#
#
# Sign up here <https://www.smuicon.com/activities>  by 8 November 2024
#
#
#
#
#
# Feel free to email us at smubarkada@sa.smu.edu.sg <mailto:smubarkada@sa.smu.edu.sg>  if you have any questions
#
# or reach out to us on Telegram:
#
#
#
# Jana (President) - @janana21
#
# Justin (Vice-President) - @justindionio
#
# Andrew (Events Director) - @andrewso1
#
#
#
# Want to know more about us?
#
# Follow us on Instagram @smu.barkada <http://instagram.com/smu.barkada>
#
#
#
#
#
# Kita Kits!
#
#
#
# Translations:
#
# Kita kits! - See you there!
#
# ?ber months ? referring to September, October, November, December,
#
# which is commonly celebrated as the Christmas season in the Philippines
#
# Parol ? Filipino ornamental lanterns for Christmas
#
#
#
# *Note: Limited slots available. You will receive a confirmation email upon successful registration.
#
# Food to be served is non-Halal and non-vegetarian.
#
#
#
#
# Should you wish to unsubscribe:
#
# Internal recipients of SMU, please visit
#
# https://smu.sg/emailrulesstudent to filter away this EDM.
#
#
#
#
#
#
#
# maple I-FOOD-TIME
# maple I-FOOD-TIME
# november B-FOOD-TIME
# 202 I-FOOD-TIME
# ##4 I-FOOD-TIME
# . I-FOOD-TIME
# 00 I-FOOD-TIME
# pm I-FOOD-TIME
# opening I-FOOD-TIME
# . I-FOOD-TIME
# 05 I-FOOD-TIME
# pm I-FOOD-TIME
# panel I-FOOD-TIME
# . I-FOOD-TIME
# 00 I-FOOD-TIME
# pm I-FOOD-TIME
# q I-FOOD-TIME
# . I-FOOD-TIME
# 20 I-FOOD-TIME
# pm I-FOOD-TIME
# concluding I-FOOD-TIME
# . I-FOOD-TIME
# 30 I-FOOD-TIME
# pm I-FOOD-TIME
# end I-FOOD-TIME
# . I-FOOD-TIME
# 30 I-FOOD-TIME
# ##pm I-FOOD-TIME
# . I-FOOD-TIME
# november B-FOOD-TIME
# 202 I-FOOD-TIME
# ##4 I-FOOD-TIME
# , I-FOOD-TIME
# 3 I-FOOD-TIME
# . I-FOOD-TIME
# 00pm I-FOOD-TIME
# ? I-FOOD-TIME
# . I-FOOD-TIME
# 30 I-FOOD-TIME
# ##pm I-FOOD-TIME
# venue I-FOOD-TIME
# stamford I-FOOD-TIME
# ##0 I-FOOD-TIME
# ) I-FOOD-TIME
# november B-FOOD-TIME
# 202 I-FOOD-TIME
# ##4 I-FOOD-TIME
# , I-FOOD-TIME
# SMU Classification: Restricted
#
#
#
#
#
# Please click here <https://business.smu.edu.sg/newsletter/4th-mapletree-real-estate-forum-smu-0>  if you are unable to view this page.
#
#
#
#
#
#
#
#
#
#
#
#
#
# 4TH MAPLETREE REAL ESTATE FORUM AT SMU
#
#
#
# The Mapletree Real Estate Programme is pleased to invite you to the 4th Mapletree Real Estate Forum at SMU on 8 November 2024.
#
#
#
# IS STUDENT ACCOMMODATION A VIABLE ASSET CLASS?
#
# Join us at this forum to explore current trends in the student housing market, the impact of changing demographics, and the rise of international student mobility. Industry experts will discuss investment returns, risk factors, and the challenges associated with this unique property sector.
#
#
#
#
#
# SPEAKER
#
#
#
#
# Mr Matt Walker
# Chief Executive Officer,
# Student Housing,
# Mapletree Investments
#
# PANELLIST
#
#
#
#
# Ms Joy Wang
# Head,
#
# ASEAN Equity Research and ASEAN Property,
#
# HSBC Bank
#
# MODERATOR
#
#
#
#
# Prof John Sequeira <https://faculty.smu.edu.sg/profile/john-sequeira-1736>
#
# Associate Professor of Finance (Practice)
# Singapore Management University
#
# ???PROGRAMME
#
# 3.00 PM
#
# Opening Remarks
#
# 3.05 PM
#
# Panel Discussion
#
# 4.00 PM
#
# Q&A
#
# 4.20 PM
#
# Concluding Remarks
#
# 4.30 PM
#
# End of Forum
#
# Light refreshments will be provided from 2.30pm.
#
#
# DATE & TIME
#
# 8 November 2024, Friday
# 3.00pm ? 4.30pm
#
#
#
# VENUE
#
# Ngee Ann Kong Si Auditorium,
# SMU School of Accountancy, Level 2
# (60 Stamford Road S178900)
#
#
#
#
#
#
#
#
#
#  <https://forms.office.com/r/SXga7a8EpH>
#
# Register by 4 November 2024, Monday.
#
# A confirmation email will be sent upon successful registration.
#
# ________________________________
#
# To unsubscribe to future mailing list, please click here <mailto:realestate@smu.edu.sg> .
#
# ? Copyright 2024 by Singapore Management University. All Rights Reserved.
#
#
#
#
#
#
#
#
#
#
# pm I-FOOD-TIME
# ?We?re excited to announce that Career Champions is collaborating with SMUSA for the SMUSA Welfare Drive: Munching on Mastery!
#
# Drop by our booth to learn more about what we do and pick up some exclusive goodies! ??
#
#
#
#
#
# (Alt text: Image displaying invitation to our Welfare Drive.)
#
#
#
# Event Details:
#
# ??? Date: 28th - 30th October (Monday ? Wednesday)
#
# ?? Time: 11 AM ? 5 PM
#
# ?? Location: SMUSA Hub
#
#
#
# Don't miss this opportunity to connect with us and discover how Career Champions can support your journey.
#
# We look forward to seeing you there! ??
#
#
#
# For any inquiries, please reach out to us at careerchampions@sa.smu.edu.sg <mailto:careerchampions@sa.smu.edu.sg> .
#
#
#
# Always stay updated! Follow us on our social media:
#
# Instagram:  @smucareerchampions <https://www.instagram.com/smucareerchampions/>
#
# LinkedIn: SMU Career Champions <https://www.linkedin.com/company/smu-career-champions/?originalSubdomain=sg>
#
# Telegram Channel: @smucc <https://t.me/smucc>
#
# TikTok: @smucareerchampions <https://www.tiktok.com/@smucareerchampions?_t=8nGWNE5jTJR&_r=1>
#
#
#
# Should you wish to unsubscribe: Internal recipients of SMU, please visit https://smu.sg/emailrulesstudent <https://iits.smu.edu.sg/sites/iits.smu.edu.sg/files/diy_guides/manage_email_address_using_rules.pdf?update>  to filter away this EDM.
#
#
#
#
# october B-FOOD-TIME
# . B-FOOD-TIME
# ##pm I-FOOD-TIME
#  <https://forms.gle/QXJmSfsR1MFFsj4K6>
#
#
#
# Dear SMUKI Members,
#
#
#
# We warmly invite you to the SMUKI Annual General Meeting 2024!
#
#
#
# This special occasion is a chance to reflect on our accomplishments over the past year and
#
# introduce the 21st SMU Komunitas Indonesia Executive Committee.
#
#
#
# Date: Saturday, 26 October 2024
#
# Time: 10.00am - 12.30pm
#
# Venue: SOE SR B1-01
#
#
#
# Kindly confirm your attendance here <https://forms.gle/QXJmSfsR1MFFsj4K6> .
#
#
#
# Light refreshments provided!
#
#
#
# We look forward to your presence as we celebrate our journey together and welcome the next chapter!
#
#
#
# Best Regards,
#
# SMUKI 20th Executive Committee
#
#
#
#
# . B-FOOD-TIME
# . B-FOOD-TIME
# - I-FOOD-TIME
# yes I-FOOD-TIME
# Join us in celebrating Thadingyut with some creative flair!
# All undergraduates are invited to our Candle Painting Event. ??????
#
#
#
#
#
# SAVE THE DATE: 1 Nov 2024 (Fri)
# ?? Time: 6.00PM - 8.30PM
# ??Location: YPHSL SR 3-02
# Yes, dinner is provided! ??
#
#
# No need to be an artist?just bring your enthusiasm! We'll provide all the materials you need to create your own beautiful candle to light up the festival. It's a perfect chance to hang out with friends, get festive, and show off your creativity. ?
#
# We have very limited spots so gather your friends and sign-up now to secure your spots!
# ??? Sign up HERE <https://www.smuicon.com/copy-of-activities> ! ??
#
#
#
#
# *Please note that food served will be non-halal and non-vegetarian.
# **Not all sign-ups are guaranteed a slot. Confirmed slots will be added to a telegram chat by 28 Oct.
#
# Should you have any queries, feel free to contact @HninTK <https://t.me/HninTK>   <https://t.me/HninTK> on Telegram!
#
#
#
#
# Stay connected with us for updates!
# Telegram: SMU Myanmar Community <https://t.me/smumyanmarcommunity>  | Instagram: @smu_mc <https://www.instagram.com/smu_mc>
#
#
#
# Should you wish to unsubscribe:
#
# Internal recipients of SMU, please visit http://smu.sg/emailrulesstudent  to filter away this EDM
#
#
#
#
#
# october B-FOOD-TIME
# . B-FOOD-TIME
# ##pm I-FOOD-TIME
#
#
#
#
#
# ?? Curious about the Commodities Industry? Want to work as a Commodities Trader after you graduate? ??
#
#
#
#
#
# Maritime Merchants Society proudly presents primers on 3 Commodities - Rapeseed, Copper and Gasoline this term.
# Join us to get the chance to network with industry professionals, and also find out more about the International Trading Track under the Finance major.
#
#
#
#
#
#
#
# Know-Thy-Commodity (KTC) 2H24 Presentation & Networking Night
#
# Organiser: Maritime Merchants Society (MMS)
#
# Event Date & Time: 25 October 2024 (Fri), 7pm - 9.30pm (refreshments provided)
#
# Venue: SMU YPHSL Seminar Room B1-01
#
#
#
# Sign-up Deadline: 20 October 2024 (Sun), 11.59pm
#
#
#
#
# If you need more info, contact maritimemerchants@sa.smu.edu.sg <mailto:maritimemerchants@sa.smu.edu.sg>
#
#
#
# We look forward to seeing you soon! ? Register Here <https://forms.office.com/pages/responsepage.aspx?id=ynmKyZpakUeiQ_Bq_WdGTWDKYGj7I3VLhkSbYujUrlFUNVlFVTNVQkFRT1kxRDAxQUgyV0tWTkVHMC4u&route=shorturl>
#
#
#
# Brought to you by:
#
# Maritime Merchants Society | LinkedIn <https://www.linkedin.com/company/maritimemerchantssociety/>  | Instagram <https://www.instagram.com/smu.mms/>  | Linktree <https://linktr.ee/smuiti>
#
#
#
#
#
# Should you wish to unsubscribe:
#
# Internal recipients of SMU, please visit  <https://smu.sg/emailrulesstudent> https://smu.sg/emailrulesstudent  <https://smu.sg/emailrulesstudent> to filter away future EDMs.
#
#
#
#
# opening I-FOOD-TIME
# . I-FOOD-TIME
# pm I-FOOD-TIME
# panel I-FOOD-TIME
# . I-FOOD-TIME
# 00 I-FOOD-TIME
# pm I-FOOD-TIME
# q I-FOOD-TIME
# . I-FOOD-TIME
# pm I-FOOD-TIME
# concluding I-FOOD-TIME
# . I-FOOD-TIME
# pm I-FOOD-TIME
# end I-FOOD-TIME
# . I-FOOD-TIME
# ##pm I-FOOD-TIME
# november B-FOOD-TIME
# 202 I-FOOD-TIME
# ##4 I-FOOD-TIME
# , I-FOOD-TIME
# . I-FOOD-TIME
# ? I-FOOD-TIME
# . I-FOOD-TIME
# 30 I-FOOD-TIME
# ##pm I-FOOD-TIME
# november B-FOOD-TIME
# ##4 I-FOOD-TIME
# , I-FOOD-TIME
# SMU Classification: Restricted
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 4TH MAPLETREE REAL ESTATE FORUM AT SMU
#
#
#
# The Mapletree Real Estate Programme is pleased to invite you to the 4th Mapletree Real Estate Forum at SMU on 8 November 2024.
#
#
#
# IS STUDENT ACCOMMODATION A VIABLE ASSET CLASS?
#
# Join us at this forum to explore current trends in the student housing market, the impact of changing demographics, and the rise of international student mobility. Industry experts will discuss investment returns, risk factors, and the challenges associated with this unique property sector.
#
#
#
#
#
# SPEAKER
#
#
#
#
# Mr Matt Walker
# Chief Executive Officer,
# Student Housing,
# Mapletree Investments
#
# PANELLIST
#
#
#
#
# Ms Joy Wang
# Head,
#
# ASEAN Equity Research and ASEAN Property,
#
# HSBC Bank
#
# MODERATOR
#
#
#
#
# Prof John Sequeira <https://faculty.smu.edu.sg/profile/john-sequeira-1736>
#
# Associate Professor of Finance (Practice)
# Singapore Management University
#
# ???PROGRAMME
#
# 3.00 PM
#
# Opening Remarks
#
# 3.05 PM
#
# Panel Discussion
#
# 4.00 PM
#
# Q&A
#
# 4.20 PM
#
# Concluding Remarks
#
# 4.30 PM
#
# End of Forum
#
# Light refreshments will be provided from 2.30pm.
#
#
# DATE & TIME
#
# 8 November 2024, Friday
# 3.00pm ? 4.30pm
#
#
#
# VENUE
#
# Ngee Ann Kong Si Auditorium,
# SMU School of Accountancy, Level 2
# (60 Stamford Road S178900)
#
#
#
#
#
#
#
#
#
#  <https://forms.office.com/r/SXga7a8EpH>
#
# Register by 4 November 2024, Monday.
#
# A confirmation email will be sent upon successful registration.
#
# ________________________________
#
# To unsubscribe to future mailing list, please click here <mailto:realestate@smu.edu.sg> .
#
# ? Copyright 2024 by Singapore Management University. All Rights Reserved.
#
#
#
#
#
#
#
# Regards,
#
# SMU Real Estate Track
#
# Lee Kong Chian School of Business
# Singapore Management University
#
#
#
#
#
# october B-FOOD-TIME
# . B-FOOD-TIME
# ##pm I-FOOD-TIME
#  <https://forms.gle/QXJmSfsR1MFFsj4K6>
#
#
#
# Dear SMUKI Members,
#
#
#
# We warmly invite you to the SMUKI Annual General Meeting 2024!
#
#
#
# This special occasion is a chance to reflect on our accomplishments over the past year and
#
# introduce the 21st SMU Komunitas Indonesia Executive Committee.
#
#
#
# Date: Saturday, 26 October 2024
#
# Time: 10.00am - 12.30pm
#
# Venue: SOE SR B1-01
#
#
#
# Kindly confirm your attendance here <https://forms.gle/QXJmSfsR1MFFsj4K6> .
#
#
#
# Light refreshments provided!
#
#
#
# We look forward to your presence as we celebrate our journey together and welcome the next chapter!
#
#
#
# Best Regards,
#
# SMUKI 20th Executive Committee
#
#
#
#
# . B-FOOD-TIME
#  <https://forms.gle/ojQtseYap498R43RA>
#
# (click on the image above to sign up!)
#
#
#
# Have a WHEELY good time with us cruising to IKEA for hotdogs and ice cream!????
#
#
#
# Session Details
#
# ???Date: Friday, 18 Oct 2024
#
# ??Training: SCIS Level 1 area outside Subway, 3.45PM - 6PM
#
# ??*Urban: SMU ? IKEA Alexandra, 7PM - 9PM
#
#
#
# *Report at Bras Basah Exit C before our urban begins!
#
# ?? Individuals are required to pass our Urban Proficiency Test (UPT) to join our urban session.
#
# Urban route difficulty: ????? ? This route has multiple road crossings and long slopes
#
#
#
# Rental Details
#
# ??skates + guards + helmet: $6 (one-time) or $12 (buy 2 get 1 free)
#
# ??guards + helmet only: $3 (one-time) or $6 (buy 2 get 1 free)
#
#
#
# Sign-ups are FCFS, closing on Tuesday, 15 Oct, 12pm.
#
# Click ??HERE <https://forms.gle/ojQtseYap498R43RA> ?? to sign up now!
#
#
#
# ?? You will be added to a Telegram group by Wednesday, 12pm if you?ve secured a slot.
#
#
#
# ?? Stay updated and follow our socials:
#
# Join our Telegram group: @SMUXSkaters <https://t.me/+7hVLwMh15S8yOThl>
#
# and follow us on Instagram: @smuxskating <https://www.instagram.com/smuxskating/>
#
#
#
# ? No tagline, just inline ?
#
#
#
#
#
#  <mailto:xplorationcrew@sa.smu.edu.sg>  <https://t.me/+7hVLwMh15S8yOThl>  <https://www.facebook.com/smuxplorationcrew/>  <https://www.instagram.com/smuxplorationcrew/>  <https://www.linkedin.com/company/smuxploration-crew/>
#
# ---------------------
#
# SMUXploration Crew 2024. All Rights Reserved.
#
#
#
# Should you wish to unsubscribe:
#
# Internal recipients of SMU, please visit https://smu.sg/emailrulesstudent <https://smu.sg/emailrulesstudent> to filter away future EDMs.
#
#
#
#
# : B-FOOD-TIME
#  <https://smu.sg/SUMMIT-2024>
#
#
#
# Excited to engage with leading companies, explore job prospects, and gain valuable insight from industry experts?
#
#
#
# Be part of the experience at SUMMIT 2024! You?ll have the chance to connect with representatives from top companies like Samsung, Exabytes, J.P. Morgan, DIS and foodpanda, while learning from our panelists as they share their professional journeys and expertise in the tech industry.
#
#
#
# ?? Date: 14 October 2024
#
# ?? Time: 7:00 PM ? 10:00 PM (Registration starts at 6:30 PM)
#
# ??Venue: SOSS/CIS Event Lobby Basement 1
#
# ?? Dress code: Smart casual
#
# ?? Dinner provided
#
# ?? Door Gifts available*
#
#
#
# This is your chance to build your network and unlock exciting opportunities! Secure your spot here <https://smu.sg/SUMMIT-2024> !
#
#
#
# Sign up closes on 14 October 2024, 6:00 PM
#
#
#
# Looking forward to seeing you there!
#
#
#
# *Door gifts are only available in limited quantity, on a first come first serve basis
#
#
#
# ________________________________
#
#
#
# Follow SMU Women in Tech:
#
# Instagram  <https://www.instagram.com/smuwit/>  | LinkedIn  <https://linkedin.com/company/smuwit>  | Telegram  <http://t.me/smuwit>
#
#
#
# ________________________________
#
#
#
# Should you wish to unsubscribe:
#
# Internal recipients of SMU, please visit
#
# https://smu.sg/emailrulesstudent to filter away this EDM
#
#
#
#
# : B-FOOD-TIME
#  <https://smu.sg/SUMMIT-2024>
#
#
#
# Excited to engage with leading companies, explore job prospects, and gain valuable insight from industry experts?
#
#
#
# Be part of the experience at SUMMIT 2024! You?ll have the chance to connect with representatives from top companies like Samsung, Exabytes, J.P. Morgan, DIS and foodpanda, while learning from our panelists as they share their professional journeys and expertise in the tech industry.
#
#
#
# ?? Date: 14 October 2024
#
# ?? Time: 7:00 PM ? 10:00 PM (Registration starts at 6:30 PM)
#
# ??Venue: SOSS/CIS Event Lobby Basement 1
#
# ?? Dress code: Smart casual
#
# ?? Dinner provided
#
# ?? Door Gifts available*
#
#
#
# This is your chance to build your network and unlock exciting opportunities! Secure your spot here <https://smu.sg/SUMMIT-2024> !
#
#
#
# Sign up closes on 14 October 2024, 6:00 PM
#
#
#
# Looking forward to seeing you there!
#
#
#
# *Door gifts are only available in limited quantity, on a first come first serve basis
#
#
#
# ________________________________
#
#
#
# Follow SMU Women in Tech:
#
# Instagram  <https://www.instagram.com/smuwit/>  | LinkedIn  <https://linkedin.com/company/smuwit>  | Telegram  <http://t.me/smuwit>
#
#
#
# ________________________________
#
#
#
# Should you wish to unsubscribe:
#
# Internal recipients of SMU, please visit
#
# https://smu.sg/emailrulesstudent to filter away this EDM
#
#
#
#
# . I-FOOD-TIME
# 45 I-FOOD-TIME
# am I-FOOD-TIME
# - I-FOOD-TIME
# . I-FOOD-TIME
# pm I-FOOD-TIME
# venue I-FOOD-TIME
#
#
#
# ?? Sign up now! ??
#
# Looking to learn more about B-to-B insurance broking and risk management? Or simply trying to explore new industries and possibilities? Look no further! SMU Aikido proudly presents this unique networking opportunity with seasoned representatives at Marsh (Singapore). Don't lose out on this chance to understand more about what they do at Marsh!
#
# Event Details
# Date: 18th October 2024, Friday
# Time: 11.45 am - 1.15 pm
# Venue: 8 Marina View, Asia Square Tower 1, Singapore 018960
# Dress code: Business casual
# *Light refreshments provided*
#
# Hurry, as sign ups are limited to 20 slots only!
# Click HERE <https://forms.gle/SwXSxucEv4wvHvdM6>  to secure your spot now!
# [Sign-ups are till 8th Oct 2024, 2359]
#
# *Do note that a confirmation email will be sent upon your registration*
#
# Any queries?
# Feel free to reach out to Hui Mei (@mintgrey) / Key (@Kry_73) on Telegram!??
#
# Follow our socials and dive deep into the world of Aikido!
# IG: @smuaikido
# Linktree: https://linktr.ee/smu_aikido <https://linktr.ee/smu_aikido>
#
# See you there!
# Warmest regards,
# SMU Aikido
#
#
# Should you wish to unsubscribe:
# Internal recipients of SMU, please visit https://smu.sg/emailrulesstudent <https://smu.sg/emailrulesstudent>  to filter away this EDM
#
#
#
#
# : B-FOOD-TIME
#  <https://smu.sg/SUMMIT-2024>
#
#
#
# Excited to engage with leading companies, explore job prospects, and gain valuable insight from industry experts?
#
#
#
# Be part of the experience at SUMMIT 2024! You?ll have the chance to connect with representatives from top companies like Samsung, Exabytes, J.P. Morgan, DIS and foodpanda, while learning from our panelists as they share their professional journeys and expertise in the tech industry.
#
#
#
# ?? Date: 14 October 2024
#
# ?? Time: 7:00 PM ? 10:00 PM (Registration starts at 6:30 PM)
#
# ??Venue: SOSS/CIS Event Lobby Basement 1
#
# ?? Dress code: Smart casual
#
# ?? Dinner provided
#
# ?? Door Gifts available*
#
#
#
# This is your chance to build your network and unlock exciting opportunities! Secure your spot here <https://smu.sg/SUMMIT-2024> !
#
#
#
# Sign up closes on 14 October 2024, 6:00 PM
#
#
#
# Looking forward to seeing you there!
#
#
#
# *Door gifts are only available in limited quantity, on a first come first serve basis
#
#
#
# ________________________________
#
#
#
# Follow SMU Women in Tech:
#
# Instagram  <https://www.instagram.com/smuwit/>  | LinkedIn  <https://linkedin.com/company/smuwit>  | Telegram  <http://t.me/smuwit>
#
#
#
# ________________________________
#
#
#
# Should you wish to unsubscribe:
#
# Internal recipients of SMU, please visit
#
# https://smu.sg/emailrulesstudent to filter away this EDM
#
#
#
#
# . I-FOOD-TIME
# 45 I-FOOD-TIME
# am I-FOOD-TIME
# - I-FOOD-TIME
# . I-FOOD-TIME
# pm I-FOOD-TIME
# venue I-FOOD-TIME
#
#
#
# ?? Sign up now! ??
#
# Looking to learn more about B-to-B insurance broking and risk management? Or simply trying to explore new industries and possibilities? Look no further! SMU Aikido proudly presents this unique networking opportunity with seasoned representatives at Marsh (Singapore). Don't lose out on this chance to understand more about what they do at Marsh!
#
# Event Details
# Date: 18th October 2024, Friday
# Time: 11.45 am - 1.15 pm
# Venue: 8 Marina View, Asia Square Tower 1, Singapore 018960
# Dress code: Business casual
# *Light refreshments provided*
#
# Hurry, as sign ups are limited to 20 slots only!
# Click HERE <https://forms.gle/SwXSxucEv4wvHvdM6>  to secure your spot now!
# [Sign-ups are till 8th Oct 2024, 2359]
#
# *Do note that a confirmation email will be sent upon your registration*
#
# Any queries?
# Feel free to reach out to Hui Mei (@mintgrey) / Key (@Kry_73) on Telegram!??
#
# Follow our socials and dive deep into the world of Aikido!
# IG: @smuaikido
# Linktree: https://linktr.ee/smu_aikido <https://linktr.ee/smu_aikido>
#
# See you there!
# Warmest regards,
# SMU Aikido
#
#
# Should you wish to unsubscribe:
# Internal recipients of SMU, please visit https://smu.sg/emailrulesstudent <https://smu.sg/emailrulesstudent>  to filter away this EDM
#
#
#
#
#
# : B-FOOD-TIME
#  <https://smu.sg/SUMMIT-2024>
#
#
#
# Excited to engage with leading companies, explore job prospects, and gain valuable insight from industry experts?
#
#
#
# Be part of the experience at SUMMIT 2024! You?ll have the chance to connect with representatives from top companies like Samsung, Exabytes, J.P. Morgan, DIS and foodpanda, while learning from our panelists as they share their professional journeys and expertise in the tech industry.
#
#
#
# ?? Date: 14 October 2024
#
# ?? Time: 7:00 PM ? 10:00 PM (Registration starts at 6:30 PM)
#
# ??Venue: SOSS/CIS Event Lobby Basement 1
#
# ?? Dress code: Smart casual
#
# ?? Dinner provided
#
# ?? Door Gifts available*
#
#
#
# This is your chance to build your network and unlock exciting opportunities! Secure your spot here <https://smu.sg/SUMMIT-2024> !
#
#
#
# Sign up closes on 14 October 2024, 6:00 PM
#
#
#
# Looking forward to seeing you there!
#
#
#
# *Door gifts are only available in limited quantity, on a first come first serve basis
#
#
#
# ________________________________
#
#
#
# Follow SMU Women in Tech:
#
# Instagram  <https://www.instagram.com/smuwit/>  | LinkedIn  <https://linkedin.com/company/smuwit>  | Telegram  <http://t.me/smuwit>
#
#
#
# ________________________________
#
#
#
# Should you wish to unsubscribe:
#
# Internal recipients of SMU, please visit
#
# https://smu.sg/emailrulesstudent to filter away this EDM
#
#
#
#
# 202 I-FOOD-TIME
# : I-FOOD-TIME
# 30 I-FOOD-TIME
# - I-FOOD-TIME
# : B-FOOD-TIME
# 00 I-FOOD-TIME
#
#
#
#
#  <https://www.smuicon.com/copy-of-activities>
#
#
#
# Looking for a fun way to explore new cultures?
#
#
#
# SMUKI x IISMA presents...
#
#
#
# ?Batik & Bites ?
#
#
#
# Come join us for an afternoon of Indonesian Culture!
#
#
#
# Through this event, you can experience the rich traditions of Indonesia through food, art, language, and games!
#
#
#
# ??What's in Store? ??
#
# Batik Painting, Indonesian Snacks, Traditional Games, Trivia, Socialize, and Mingle!
#
#
#
# ?? Date: Friday, 18 October 2024
#
# ?? Time: 15:30 - 18:00
#
# ?? Venue: SOE SR B1-1
#
#
#
# ?? Limited slots available? RSVP now through this LINK <https://www.smuicon.com/copy-of-activities> !
#
#
#
# Stay in the loop?follow us on Instagram @smu_ki <http://instagram.com/smu_ki>  for all the latest updates!
#
# For further inquiries, please contact @nathaliesurya <https://t.me/nathaliesurya>  on Telegram.
#
# We can't wait to share this cultural experience with you! ???
#
#
#
# Should you wish to unsubscribe:
# Internal recipients of SMU, please visit https://smu.sg/emailrulesstudent to filter away this EDM
#
#
#
#
#
#
# oct B-FOOD-TIME
# ##pm B-FOOD-TIME
#
#
#
#
# Hey SMU Moo-niacs!?? Want to chill out this recess week?
#
# Join us at Sentosa Palawan Beach for a FREE scoop of our new Summer Fan Faves ice creams!?????
#
#
#
# Try our Scoop Shop superstar ??Marshmallow Sky?? or the popular ??Strawberry Cheesecake?? now with a Non-Dairy recipe! Or if you're feeling it, both!??
#
#
#
# See you there 4-6 Oct, 12pm - 8pm ??
#
#
#
# Follow us on our socials for more information!
#
# IG: @benandjerrysg
#
# #BenandJerrySG #SummerFanFaves
#
# -
#
# Proudly brought to you by:
#
# SMU BIZCOM
#
# The Business Development & Partnerships Arm of SMUSA
#
# Website <https://www.smubizcom.com/>  | Telegram Channel <https://t.me/SMUPROMOS>  | Facebook <https://www.facebook.com/bizcom.smu/>  | Instagram <https://www.instagram.com/smubizcom/?hl=en>  | TikTok <https://vt.tiktok.com/ZSR1Gr37S>
#
# To unsubscribe, please visit https://smu.sg/emailrules <https://smu.sg/emailrules>  to filter away this EDM
#
#
#
#
#
#
#
#
#
#
# : B-FOOD-TIME
# Dear ACF Club Exco Members,
#
# Thank you for RSVPing for ACF's Internal Elections.
#
# ACF Internal Elections 2024
# Dates: 6 & 7 October (Sunday & Monday)
# Timing: 10:00 AM - 6:00 PM for both dates
# Venue: SOE/SCIS2 SR B1-1 for both dates
# Attire: Smart Casual
#
# Please bring a blue / black pen for casting your votes on both days.
#
# Lunch will be provided for you if you're attending before 12:30pm.
#
# More details regarding Internal Elections will be shared on actual days.
#
# If there are any changes to your attendance on either days, please pm me ASAP.
#
# If you'll be late on either day, please pm me on the actual day too.
#
# On behalf of the 20th ACF Management Committee, we look forward to seeing you to vote for our 21st ACF Management Committee!
#
# Warmest Regards
#
#
# ________________________________
#
# From: SMU Arts & Cultural Fraternity
# Sent: Friday, 20 September 2024 11:35 pm
# To: SMU Ardiente <ardiente@sa.smu.edu.sg>; SMU Artdicted <artdicted@sa.smu.edu.sg>; SMU Ballare <ballare@sa.smu.edu.sg>; SMU Broadcast & Entertainment <smube@sa.smu.edu.sg>; SMU Caderas Latinas <caderaslatinas@sa.smu.edu.sg>; SMU Chamber Choir <chamberchoir@sa.smu.edu.sg>; SMU Chinese Orchestra <smuco@sa.smu.edu.sg>; SMU Eurhythmix <eurhythmix@sa.smu.edu.sg>; SMU Funk Movement <funkmovement@sa.smu.edu.sg>; SMU Guitarissimo <guitarissimo@sa.smu.edu.sg>; SMU INDANCITY <indancity@sa.smu.edu.sg>; SMU Ivory Keys <ivorykeys@sa.smu.edu.sg>; SMU Literati <literati@sa.smu.edu.sg>; SMU Malay Language & Cultural Club <mlcc@sa.smu.edu.sg>; SMU Samba Masala <samba@sa.smu.edu.sg>; SMU SoundFoundry <soundfoundry@sa.smu.edu.sg>; SMU Stageit <stageit@sa.smu.edu.sg>; SMU Stereometa <stereometa@sa.smu.edu.sg>; SMU Symphonia <symphonia@sa.smu.edu.sg>; SMU VOIX <smuvoix@sa.smu.edu.sg>; SMUSAIC <smusaic@sa.smu.edu.sg>
# Cc: WEE E-Chiing <ecwee@smu.edu.sg>; ACF President, SMUSA <pres.acf@sa.smu.edu.sg>; KIU Yong Jen <yongjen.kiu.2022@business.smu.edu.sg>; Kimberly TAY Khai Iun <kimberlytay.2022@business.smu.edu.sg>; TAN Ee Tai <eetai.tan.2023@economics.smu.edu.sg>; Edmund KHOO Han Guang <edmund.khoo.2021@business.smu.edu.sg>; Lia Isabella Bawasanta KATIPUNAN <lkatipunan.2022@accountancy.smu.edu.sg>; Selina CHAI Xinyu <selinachai.2022@accountancy.smu.edu.sg>; Jovan WANG Ying Ming <jovan.wang.2023@scis.smu.edu.sg>; MOK Tze Yuen <tzeyuen.mok.2023@business.smu.edu.sg>; MAGDADARO Ellyzse Marcee F <e.magdadaro.2023@business.smu.edu.sg>; Sumedhaa SATHIYANARAYANAN <sumedhaas.2022@economics.smu.edu.sg>; LOH Ee Hsuen <eehsuen.loh.2022@law.smu.edu.sg>; WONG Jing Wen <jwwong.2022@business.smu.edu.sg>; Victoria Frances LOH <victorialoh.2023@socsc.smu.edu.sg>; GAN Pei Yun <peiyun.gan.2022@business.smu.edu.sg>; Preston CHUA Wee Ming <prestonchua.2023@socsc.smu.edu.sg>; Melody WONG Xin Hui <melody.wong.2022@scis.smu.edu.sg>
# Subject: [ACF] Invitation to ACF Internal Elections 2024
#
# Dear ACF Clubs,
#
# This email is to formally invite you to attend ACF's Internal Elections 2024. Event Details are as follow:
#
# ACF Internal Elections 2024
# Dates: 6 & 7 October (Sunday & Monday)
# Timing: 10:00 AM - 6:00 PM for both dates
# Venue: SOE/SCIS2 SR B1-1 for both dates
#
# ACF originally set our IE to be on 5 & 6 October (Saturday and Sunday of Week 7). However, a few of our nominees already have existing commitments on 5 October before the start of the Academic Year after checking with them. Hence, we have decided to amend our IE dates. This is taking into consideration of efficiency and to maximise the use of our time.
#
# We seek your assistance to gather your Outgoing and Incoming Exco's availability for both dates. As long as there are 2 Outgoing and Incoming Exco members represented by all clubs at all times, that's sufficient. Preferably both Exco members are from the incoming Exco so that they are able to choose their incoming MC members. This is a crucial factor for them as they'll be working together with our incoming MC for 2025.
#
# Please RSVP here <https://forms.office.com/Pages/ResponsePage.aspx?id=ynmKyZpakUeiQ_Bq_WdGTW2jaVVhJ0xAhZ-KmEV6h5ZURVM1UklKT1pWQjMyUVFUOUlIODA1RzA4Ty4u>  by 29 September (Sunday). If your club is unable to have 2 Exco members at any point during IE, please pm me ASAP with reason.
#
# We look forward to meeting you during ACF IE!
#
# Thank you.
#
# Warmest Regards
#
#
#
#
#
# . I-FOOD-TIME
# 45 I-FOOD-TIME
# am I-FOOD-TIME
# - I-FOOD-TIME
# . I-FOOD-TIME
# pm I-FOOD-TIME
# venue I-FOOD-TIME
#
#
#
# ?? Sign up now! ??
#
# Looking to learn more about B-to-B insurance broking and risk management? Or simply trying to explore new industries and possibilities? Look no further! SMU Aikido proudly presents this unique networking opportunity with seasoned representatives at Marsh (Singapore). Don't lose out on this chance to understand more about what they do at Marsh!
#
# Event Details
# Date: 18th October 2024, Friday
# Time: 11.45 am - 1.15 pm
# Venue: 8 Marina View, Asia Square Tower 1, Singapore 018960
# Dress code: Business casual
# *Light refreshments provided*
#
# Hurry, as sign ups are limited to 20 slots only!
# Click HERE <https://forms.gle/SwXSxucEv4wvHvdM6>  to secure your spot now!
# [Sign-ups are till 8th Oct 2024, 2359]
#
# *Do note that a confirmation email will be sent upon your registration*
#
# Any queries?
# Feel free to reach out to Hui Mei (@mintgrey) / Key (@Kry_73) on Telegram!??
#
# Follow our socials and dive deep into the world of Aikido!
# IG: @smuaikido
# Linktree: https://linktr.ee/smu_aikido <https://linktr.ee/smu_aikido>
#
# See you there!
# Warmest regards,
# SMU Aikido
#
#
# Should you wish to unsubscribe:
# Internal recipients of SMU, please visit https://smu.sg/emailrulesstudent <https://smu.sg/emailrulesstudent>  to filter away this EDM
#
#
#
#
# - I-FOOD-TIME
# : B-FOOD-TIME
# : B-FOOD-TIME
# : B-FOOD-TIME
#
#
#
#
#
# ?? Join Us at Sustainable Investment Summit 2024! ??
#
#
#
# Network with industry leaders and changemakers, and discover the latest sustainable investment insights at SIS 2024. Let's collaborate to drive innovation and a greener future.
#
#
#
# Event Details:
#
# ?? 10 October | ?? 4:10-9:30 PM |?? SOL Function Lounge & Connexion Level 3 | ?? Business Casual
#
#
#
# Event Timeline for Programme Highlights:
# Information Session - 4:10 - 4:55 PM
#
# Panel Discussion -  6:20 - 7:30 PM
#
# Networking Session - 7:50 - 9:30 PM
#
#
#
# *Tea Reception, Dinner & Registration starts 30 minutes before each segment.
#
#
#
# Don't miss this opportunity! Slots for this event are limited.
#
#
#
# Registration closes TONIGHT, 2 October 2024 11:59 PM.
#
#
#
# Sign Up HERE <https://forms.gle/nPhNgSwx1NXG5KpZ7> .
#
#
#
# Note:
#
# *Participants may attend any or all of the 3 events - subjected to availability. Sign-ups are on a first come, first serve basis and you will receive a confirmation email upon successful registration.
#
#
#
# *If you wish to sign up as a pair and be allocated to the same table (for networking segment only), both of you are to submit this registration form individually, at the same time. For more information regarding the Pair Sign-Ups, please refer to the registration form.
#
#
#
# Should you wish to unsubscribe:
#
# Internal recipients of SMU, please visit https://smu.sg/emailrulesstudent <https://smu.sg/emailrulesstudent> ?to filter away this EDM
#
#
#
#
#
#
#
#
# : B-FOOD-TIME
# - I-FOOD-TIME
# : B-FOOD-TIME
# 00 I-FOOD-TIME
#
#
#
#
#  <https://www.smuicon.com/copy-of-activities>
#
#
#
# Looking for a fun way to explore new cultures?
#
#
#
# SMUKI x IISMA presents...
#
#
#
# ?Batik & Bites ?
#
#
#
# Come join us for an afternoon of Indonesian Culture!
#
#
#
# Through this event, you can experience the rich traditions of Indonesia through food, art, language, and games!
#
#
#
# ??What's in Store? ??
#
# Batik Painting, Indonesian Snacks, Traditional Games, Trivia, Socialize, and Mingle!
#
#
#
# ?? Date: Friday, 18 October 2024
#
# ?? Time: 15:30 - 18:00
#
# ?? Venue: SOE SR B1-1
#
#
#
# ?? Limited slots available? RSVP now through this LINK <https://www.smuicon.com/copy-of-activities> !
#
#
#
# Stay in the loop?follow us on Instagram @smu_ki <http://instagram.com/smu_ki>  and join our Telegram group <https://t.me/+6eacFznSUN4xMmY1>  for all the latest updates!
#
# For further inquiries, please contact @nathaliesurya <https://t.me/nathaliesurya>  on Telegram.
#
# We can't wait to share this cultural experience with you! ???
#
#
#
# Should you wish to unsubscribe:
# ...
#
#
#
#
# february B-FOOD-TIME
# . B-FOOD-TIME
# – I-FOOD-TIME
# . B-FOOD-TIME
# ( I-FOOD-TIME
# . B-FOOD-TIME
# 45 I-FOOD-TIME
# ##pm I-FOOD-TIME
# . B-FOOD-TIME
#
#
#
#
#
# SCIS REUNION 2024: NOSTALGIAFEST
#
#  <https://bit.ly/nostalgia-fest-24>
#
# FOOD, BONDING, AND A FUN, FUN NIGHT 🥳
#
#
#
# YOU are invited to SCIS Reunion 2024: NostalgiaFest! 🤩
#
#
#
# Come for a night of fun, food, and games with your friends and SCIS alumni! Look forward to bringing home attractive prizes on this special night to remember ✨
#
#
#
# Block out your calendar!
#
# Date: Thursday, 8 February 2024
#
# Time: 6.00pm – 9.00pm (registration starts at 5.45pm)
#
# Venue: SOSS/CIS Event Lobby
#
# Dress Code: Smart Casual/Retro-themed
#
#
#
# There is no better way to start off the new year 🤗 See you there!
#
#
#
# Sign up at https://bit.ly/nostalgia-fest-24
#
#
#
# Registration closes Wednesday, 7 February 2024, 11.59pm.
#
#
#
# Should you have any queries, feel free to contact Michelle @ <https://t.me/zzzzzixuan> tehpingcaifan
#
# or Jess Myn @ <https://t.me/jessicafiore> jesszmyn on Telegram!
#
#
#
# Brought to you by Ellipsis, the student representative body of
# School of Computing and Information Systems (SCIS)
#
#
#
# Facebook <https://www.facebook.com/SMUELLIPSIS/>  | Instagram <https://www.instagram.com/smuellipsis/>  | LinkedIn <https://sg.linkedin.com/company/ellipsis-smu-computing-and-information-systems-society>  | Telegram <https://t.me/scisbytes>
#
# Website: ellipsis.scis.smu.edu.sg <https://ellipsis.scis.smu.edu.sg/>
#
# Email: ellipsis@sa.smu.edu.sg <mailto:ellipsis@sa.smu.edu.sg>
#
#
#
# Should you wish to unsubscribe:
#
# Internal recipients of SMU, please visit https://smu.sg/emailrulesstudent <https://smu.sg/emailrulesstudent> .
#
#
#
#
#
#
#
#
# & I-FOOD-TIME
# . I-FOOD-TIME
# ##pm I-FOOD-TIME
# - I-FOOD-TIME
# ##pm I-FOOD-TIME
# rex I-FOOD-TIME
# - I-FOOD-TIME
# first I-FOOD-TIME
# Ever wanted to bake your own homemade pastries?
#
#
#
# Join us at our event -
#
# ✨ Chinese New Year Baking Workshop ✨
#
# and learn how to make traditional Pineapple Tarts 😋!
#
#
#
#  <https://www.smuicon.com/copy-of-activities>
#
#
#
# Participants will be able to bring their pineapple tarts home!
#
# –
#
# 2 & 16  February 2024
#
# 2.45PM-6PM
#
# REX House Baking Studio
#
# (To gather at SOE SR 3-4 first)
#
#
#
# Initial Cost: $70
#
# Sign-up Fee: $10
#
# –
#
#  SIGN UP NOW! <https://www.smuicon.com/copy-of-activities>
#
#
#
# **Do note that your slot will only be confirmed when full payment has been made!
#
#
#
# The closing date for registration is 31 Jan 2024!
#
#
#
#  Follow us on Instagram: @smu_tm <https://www.instagram.com/smu.tm/>  for our latest updates!
#
#
#
# Should you wish to unsubscribe:
#
# Internal recipients of SMU, please visit https://smu.sg/emailrulesstudent <https://smu.sg/emailrulesstudent>  to filter away this EDM
#
#
#
#
# ##pm I-FOOD-TIME
# – I-FOOD-TIME
# ##pm I-FOOD-TIME
# ) I-FOOD-TIME
# ##am I-FOOD-TIME
# – I-FOOD-TIME
# ##pm I-FOOD-TIME
#
#
#
#
#
#
# Happy Lunar New Year!
#
#
#
# Use your angbao money wisely this CNY by celebrating it with a fun and energetic badminton session to burn off calories from all the delicious CNY snacks!
#
#
#
# On that note, we have lowered the prices for our recreational sessions E and F! Gather your friends and come join us @SMU Administration Building, MPSH!
#
#
#
# *Slots for recreational badminton are allocated on a first-come-first-serve basis.
#
#
#
# Session D: 2nd February 2024 (Friday, 3pm–5pm) ($8)
#
# Session E: 6th February 2024 & 20th February 2024 (Tuesday, 9am–12pm) ($10)
#
# Session F: 16th February 2024 & 23rd February 2024 (Friday, 3pm–5pm) ($14)
#
# 24 pax/session
#
#
#
# ** Slots will only be confirmed after completion of the registration form and payment, A confirmation message will be sent via telegram **
#
#
#
# Register HERE <https://docs.google.com/forms/d/e/1FAIpQLSe0hX-YXUC3SkgU0HTxkZ1V_S6Dt44QrOYNdxrlI_QSogKE2g/viewform?usp=sf_link>
#
#
#
# Do follow our Instagram <https://instagram.com/smubadminton?igshid=NGVhN2U2NjQ0Yg==>  Page and Telegram <https://t.me/SMUBadminton>  Channel for the latest news!
#
#
#
# Sign up now! We look forward to seeing you :-)
#
#
#
# If you have any questions, do reach out to Jovan (@ong_cs) on Telegram.
#
#
#
# Should you wish to unsubscribe:
#
# Internal recipients of SMU, please visit https://smu.sg/emailrulesstudent <https://smu.sg/emailrulesstudent>  to filter away this EDM
#
#
#
#
# & I-FOOD-TIME
# . I-FOOD-TIME
# ##pm I-FOOD-TIME
# - I-FOOD-TIME
# ##pm I-FOOD-TIME
# rex I-FOOD-TIME
# - I-FOOD-TIME
# first I-FOOD-TIME
# Ever wanted to bake your own homemade pastries?
#
# Join us at our event -
# ✨ Chinese New Year Baking Workshop ✨
# and learn how to make traditional Pineapple Tarts 😋!
#
#  <https://www.smuicon.com/copy-of-activities>
#
# Participants will be able to bring their pineapple tarts home!
# –
# 2 & 16  February 2024
# 2.45PM-6PM
# REX House Baking Studio
# (To gather at SOE SR 3-4 first)
#
# Initial Cost: $70
# Sign-up Fee: $10
# –
#  SIGN UP NOW! <https://www.smuicon.com/copy-of-activities>
#
# **Do note that your slot will only be confirmed when full payment has been made!
#
# The closing date for registration is 31 Jan 2024!
#
#   Follow us on Instagram: @smu_tm <https://www.instagram.com/smu.tm/>  for our latest updates!
#
# Should you wish to unsubscribe:
#
# Internal recipients of SMU, please visit https://smu.sg/emailrulesstudent <https://smu.sg/emailrulesstudent>  to filter away this EDM
#
#
#
#
#
#
#
#
#
#
# ##pm I-FOOD-TIME
# ##pm I-FOOD-TIME
# . B-FOOD-TIME
# 30 I-FOOD-TIME
# ##pm I-FOOD-TIME
#
#
#
#
# Dear Students,
#
#
#
# You are cordially invited to attend the Closing Ceremony of our Stock Trading Competition 2024! Don’t miss this opportunity to watch our finalists deliver their winning pitches! Refreshments will be provided.
#
#
#
# Details of the Closing Ceremony
#
# Date: Tuesday, 30th January 2024
#
# Time: 7pm - 9pm
#
# Location: SMU Admin Building Function Room 6-1
#
#
#
# If you are interested in attending, do fill up the registration form here <https://forms.gle/WAejeEcUaMS6t1mQ9> .
#
#
#
# Registration for the event will begin at 6.30pm. Kindly ensure that you are seated by 6.55pm.
#
#
#
# We look forward to seeing you there!
#
#
#
# Follow us on our social media below!
#
# Website <https://www.smueye.com/>  | Instagram <https://www.instagram.com/eyeinvestment/>  | LinkedIn <https://www.linkedin.com/company/eyeinvestment>  | Facebook
#
# <https://www.facebook.com/smueye/>
#
#
#
#  Should you wish to unsubscribe:
#
# Internal recipients of SMU, please visit https://smu.sg/emailrulesstudent <https://smu.sg/emailrulesstudent>  to filter away this EDM
#
#
#
#
#
#
# ##pm I-FOOD-TIME
# – I-FOOD-TIME
# ##pm I-FOOD-TIME
# ) I-FOOD-TIME
# ##am I-FOOD-TIME
# – I-FOOD-TIME
# ##pm I-FOOD-TIME
#
#
#
#
#
#
# Happy Lunar New Year!
#
#
#
# Use your angbao money wisely this CNY by celebrating it with a fun and energetic badminton session to burn off calories from all the delicious CNY snacks!
#
#
#
# On that note, we have lowered the prices for our recreational sessions E and F! Gather your friends and come join us @SMU Administration Building, MPSH!
#
#
#
# *Slots for recreational badminton are allocated on a first-come-first-serve basis.
#
#
#
# Session D: 2nd February 2024 (Friday, 3pm–5pm) ($8)
#
# Session E: 6th February 2024 & 20th February 2024 (Tuesday, 9am–12pm) ($10)
#
# Session F: 16th February 2024 & 23rd February 2024 (Friday, 3pm–5pm) ($14)
#
# 24 pax/session
#
#
#
# ** Slots will only be confirmed after completion of the registration form and payment, A confirmation message will be sent via telegram **
#
#
#
# Register HERE <https://docs.google.com/forms/d/e/1FAIpQLSe0hX-YXUC3SkgU0HTxkZ1V_S6Dt44QrOYNdxrlI_QSogKE2g/viewform?usp=sf_link>
#
#
#
# Do follow our Instagram <https://instagram.com/smubadminton?igshid=NGVhN2U2NjQ0Yg==>  Page and Telegram <https://t.me/SMUBadminton>  Channel for the latest news!
#
#
#
# Sign up now! We look forward to seeing you :-)
#
#
#
# If you have any questions, do reach out to Jovan (@ong_cs) on Telegram.
#
#
#
# Should you wish to unsubscribe:
#
# Internal recipients of SMU, please visit https://smu.sg/emailrulesstudent <https://smu.sg/emailrulesstudent>  to filter away this EDM
#
#
#
#
#
#
#
#
# . B-FOOD-TIME
# . B-FOOD-TIME
#
#
#
#
#
# DEDICATE A GIFT TO THAT SPECIAL SOMEONE!
#
#  <https://t.me/scisbytes>
#
# We’re back with our annual Ellipsis’ Valentine’s Welfare Drive! 💝💖
#
#
#
# Dedicate a special Valentine’s Day welfare pack 💌 to your significant someone this Valentine’s 💋, filled with a handpicked selection of goodies guaranteed to put a smile on their face🥰!
#
#
#
# Spread the love, share the joy, and make this Valentine’s truly meaningful 🧑‍🤝‍🧑! Signups are coming soon!
#
#
#
# Collection Details
#
# Date: Wednesday, 14 February 2024
#
# Time: 12.00pm – 5.00pm
#
# Venue: SCIS1 CR 3-1
#
#
#
# The link 🔗​ to sign up will be released exclusively through Ellipsis' Telegram channel <https://t.me/scisbytes>  on Thursday, 25 January 2023, at a random time between 12.00pm – 10.00pm. Make sure to join the channel and keep your notifications on so you don't miss out!
#
#
#
# Should you have any queries, feel free to contact us via telegram JR (@immaBEAST) or Ryan (@swaglord57)!
#
#
#
# Brought to you by Ellipsis, the student representative body of
# School of Computing and Information Systems (SCIS)
#
#
#
# Facebook <https://www.facebook.com/SMUELLIPSIS/>  | Instagram <https://www.instagram.com/smuellipsis/>  | LinkedIn <https://sg.linkedin.com/company/ellipsis-smu-computing-and-information-systems-society>  | Telegram <https://t.me/scisbytes>
#
# Website: ellipsis.scis.smu.edu.sg <https://ellipsis.scis.smu.edu.sg/>
#
# Email: ellipsis@sa.smu.edu.sg <mailto:ellipsis@sa.smu.edu.sg>
#
#
#
# Should you wish to unsubscribe:
#
# Internal recipients of SMU, please visit https://smu.sg/emailrulesstudent <https://smu.sg/emailrulesstudent> .
#
#
#
#
#
#
#
#
# ##pm I-FOOD-TIME
# ##pm I-FOOD-TIME
#  <https://forms.office.com/r/ieS7cxDR5U>
#
#
#
# ATTENTION STUDENTS ‼️
#
# If you haven’t already heard, SMU Career Champions will be organising our annual Professional Networking Night this February! 🪐
#
# Get a chance to connect with like-minded peers as well as industry professionals from these companies✨
#
#
#
# Limited slots are available so reserve your spot here <https://forms.office.com/r/ieS7cxDR5U>  NOW! 🔥
#
# Sign-ups close 31 January. See you there!! 🚀
#
#
# 📆 Date: 8 February 2024
# 🕓 Time: 7pm-10pm
# 🚀 Location: Connexion Level 5
# 👔 Dress Code: Business Casual
#
# 🍱 Buffet dinner provided
#
#
#
# Click here <https://www.canva.com/design/DAF6VTLzA64/2lh8KneZ2zMgS9UPx4-kEg/view?utm_content=DAF6VTLzA64&utm_campaign=designshare&utm_medium=link&utm_source=editor>  to see the professionals who will be coming down to the event (more TBC!)
#
#
#
#
#
# If you have any questions, feel free to reach out to us at careerchampions@sa.smu.edu.sg <mailto:careerchampions@sa.smu.edu.sg>
#
#
#
# Always stay updated! Follow us on our social media:
#
# Instagram:  @smucareerchampions
#
# LinkedIn: SMU Career Champions
#
# Telegram Channel: SMU Career Champions
#
#
#
# Should you wish to unsubscribe:
#
# Internal recipients of SMU, please visit https://smu.sg/emailrules <https://smu.sg/emailrules> , for instructions on how to filter away this EDM
#
#
#
#
#
#
# feb B-FOOD-TIME
# ##4 I-FOOD-TIME
# , I-FOOD-TIME
# : I-FOOD-TIME
# 15 I-FOOD-TIME
# pm I-FOOD-TIME
# - I-FOOD-TIME
# pm I-FOOD-TIME
# venue I-FOOD-TIME
# what I-FOOD-TIME
#  🐲 Celebrate Chinese New Year with us this year! 🐲
#
#
# Learn about the culture and history of Chinese New Year, participate in a Chinese Calligraphy Workshop held by experts, and learn how to use red packets to make decorations. Snacks will be provided! 🏮🧨🧧
#
#
#  <https://www.smuicon.com/copy-of-activities>
#
#
#
# Event Details
#
# Date: 2 Feb 2024, Friday
#
# Time: 6:15 PM - 9 PM
#
# Venue: LKCSB Seminar Room 1-2
#
#
#
# What are you waiting for?
#
# Sign up HERE <https://forms.gle/yH2GjDNoYFFYfJvs5>  now!
#
#
#
#
# Sign-ups close on 24 Jan, 2359hrs, or when slots are filled!
#
# *Kindly note that your slot is only confirmed when you are added to the Telegram group chat.
#
#
#
#  Follow us on Instagram: @smuroots <https://www.instagram.com/smuroots/?hl=en>  for our latest updates!
#
#
#
#
#
#
#
# Should you wish to unsubscribe:
#
# Internal recipients of SMU, please visit https://smu.sg/emailrulesstudent to filter away this EDM
#
#
#
#
# ##pm I-FOOD-TIME
# – I-FOOD-TIME
# ##pm I-FOOD-TIME
# ) I-FOOD-TIME
# ##am I-FOOD-TIME
# – I-FOOD-TIME
# ##pm I-FOOD-TIME
#
#
#
#
#
#
# Happy Lunar New Year!
#
#
#
# Use your angbao money wisely this CNY by celebrating it with a fun and energetic badminton session to burn off calories from all the delicious CNY snacks!
#
#
#
# On that note, we have lowered the prices for our recreational sessions E and F! Gather your friends and come join us @SMU Administration Building, MPSH!
#
#
#
# *Slots for recreational badminton are allocated on a first-come-first-serve basis.
#
#
#
# Session D: 2nd February 2024 (Friday, 3pm–5pm) ($8)
#
# Session E: 6th February 2024 & 20th February 2024 (Tuesday, 9am–12pm) ($10)
#
# Session F: 16th February 2024 & 23rd February 2024 (Friday, 3pm–5pm) ($14)
#
# 24 pax/session
#
#
#
# ** Slots will only be confirmed after completion of the registration form and payment, A confirmation message will be sent via telegram **
#
#
#
# Register HERE <https://docs.google.com/forms/d/e/1FAIpQLSe0hX-YXUC3SkgU0HTxkZ1V_S6Dt44QrOYNdxrlI_QSogKE2g/viewform?usp=sf_link>
#
#
#
# Do follow our Instagram <https://instagram.com/smubadminton?igshid=NGVhN2U2NjQ0Yg==>  Page and Telegram <https://t.me/SMUBadminton>  Channel for the latest news!
#
#
#
# Sign up now! We look forward to seeing you :-)
#
#
#
# If you have any questions, do reach out to Jovan (@ong_cs) on Telegram.
#
#
#
# Should you wish to unsubscribe:
#
# Internal recipients of SMU, please visit https://smu.sg/emailrulesstudent <https://smu.sg/emailrulesstudent>  to filter away this EDM
#
#
#
#
# feb I-FOOD-TIME
# ##4 I-FOOD-TIME
# , I-FOOD-TIME
# . I-FOOD-TIME
# 15 I-FOOD-TIME
# pm I-FOOD-TIME
# - I-FOOD-TIME
# pm I-FOOD-TIME
# venue I-FOOD-TIME
# - I-FOOD-TIME
# what I-FOOD-TIME
# 🐲 Celebrate Chinese New Year with us this year! 🐲
#
#
# Learn about the culture and history of Chinese New Year, participate in a Chinese Calligraphy Workshop held by experts, and learn how to use red packets to make decorations. Snacks will be provided! 🏮🧨🧧
#
#
#  <https://www.smuicon.com/copy-of-activities>
#
#
#
#
#
# Event Details
#
# Date: 2 Feb 2024, Friday
#
# Time: 6.15 PM - 9 PM
#
# Venue: LKCSB Seminar Room 1-2
#
#
#
# What are you waiting for?
#
# Sign up HERE <https://forms.gle/yH2GjDNoYFFYfJvs5>  now!
#
#
#
#
# Sign-ups close on 24 Jan, 2359hrs or when slots are filled!
#
# *Kindly note that your slot is only confirmed when you are added to the Telegram group chat.
#
#
#
#  Follow us on Instagram: @smuroots <https://www.instagram.com/smuroots/?hl=en>  for our latest updates!
#
#
#
#
#
#
#
# Should you wish to unsubscribe:
#
# Internal recipients of SMU, please visit https://smu.sg/emailrulesstudent to filter away this EDM
#
#
#
#
# - I-FOOD-TIME
# ##pm I-FOOD-TIME
# - I-FOOD-TIME
# : B-FOOD-TIME
# ##pm I-FOOD-TIME
#  <https://docs.google.com/forms/d/e/1FAIpQLSeLTJIIhIQ-QU15LDE3Gf0nqsYqXwwCOSFFq_Y5HggbdUbEbg/viewform>
#
#
#
#
# Hello Buddies! 🎉
#
#
#
# Welcome to SMU Buddy Programme!
#
#  Are you ready to get your game on?
#
#
#
# SMU Buddy Programme: Bowling Buddies
#
#
#
# 📍 Date: 26 January 2024 (Friday)
# 📍 Time: Bowling: 2-5pm, Dinner + Games: 5-8:30pm
#
# 📍 Venue: Sonic Bowl, SAFRA Punggol / SMU YPHSL Seminar Room 2-04
#
# 📍 Sign up Fee: $5
#
#
#
# 🌟Join us for a friendly game of bowling followed by a night of fun and games!🎊
#
# (Two way transportation to and from SMU will be provided)
#
#
#
# See you there!
#
# SIGN UP HERE <https://forms.gle/uyMdZidEDovAcPB26>
#
#
#
# Don't miss out! Invite your buddies and let's make it an unforgettable night! 😄🎉
#
#
#
#
#
# For more information, you may reach out to us at:
#
# Eunice Chai Enyun
#
# Telegram: @Eunchai7
#
# Email: Eunicechai.2022@economics.smu.edu.sg <mailto:Eunicechai.2022@economics.smu.edu.sg>
#
#
#
# Nathalie Surya Firmansyah
#
# Telegram: @nathaliesurya
#
# Email: nathalies.f.2023@economics.smu.edu.sg <mailto:nathalies.f.2023@economics.smu.edu.sg>
#
#
#
# Gabriel Chua Jing De
#
# Telegram: @deseyebags
#
# Email: gabrielchua.2022@scis.smu.edu.sg <mailto:gabrielchua.2022@scis.smu.edu.sg>
#
#
#
# Should you wish to unsubscribe:
#
# Internal recipients of SMU, please visit smu.sg/emailrules <http://smu.sg/emailrules> , to filter away future EDMs.
